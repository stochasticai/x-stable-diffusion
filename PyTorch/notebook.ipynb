# %%
# !pip install -q stochasticx

# %%
from stochasticx.local.stable_diffusion import init, generate_images

model = init()
# Out:
# [+] Downloading the model
# 100%|██████████| 2.53G/2.53G [01:39<00:00, 25.4MiB/s]
# [+] Model downloaded
# [+] Loading model
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# [+] Model loaded

# %%
generate_images(
    model,
    prompt=["Riding a horse"]
)[0]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC84437DE10>
